# %% [markdown]
# ### Install necessary packages

# %%
# %pip install numpy
# %pip install GPy
# %pip install scipy
# %pip install keras
# %pip install matplotlib
# %pip install pandas
# %pip install scikit-learn
# %pip install tensorflow
# Out:
# Requirement already satisfied: numpy in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (1.26.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: GPy in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (1.13.2)
# Requirement already satisfied: numpy<2.0.0,>=1.7 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from GPy) (1.26.4)
# Requirement already satisfied: six in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from GPy) (1.16.0)
# Requirement already satisfied: paramz>=0.9.6 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from GPy) (0.9.6)
# Requirement already satisfied: cython>=0.29 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from GPy) (3.0.11)
# Requirement already satisfied: scipy<=1.12.0,>=1.3.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from GPy) (1.12.0)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from paramz>=0.9.6->GPy) (5.1.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (1.12.0)
# Requirement already satisfied: numpy<1.29.0,>=1.22.4 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from scipy) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: keras in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (3.6.0)
# Requirement already satisfied: absl-py in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from keras) (13.9.3)
# Requirement already satisfied: namex in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from keras) (3.12.1)
# Requirement already satisfied: optree in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from keras) (0.13.0)
# Requirement already satisfied: ml-dtypes in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.2)
# Requirement already satisfied: six>=1.5 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (2.18.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (5.28.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (58.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.67.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.6.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.31.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.9.3)
# Requirement already satisfied: namex in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.6)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (8.5.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.20.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\kgy90\onedrive\문서\github\deepkriging_self\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import scipy.stats as stats
##Library neural nets
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
# Library for Gaussian process
import GPy
##Library for visualization
import matplotlib as mpl
mpl.style.use("seaborn-v0_8")
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import matplotlib; matplotlib.rcParams['figure.figsize'] = (8,6)
from sklearn.preprocessing import MinMaxScaler
import pylab

# %% [markdown]
# ### Split into input (X) and output (Y) variables

# %%
N = 1000 ##Sample Size
P = 1 ##Covariates
M = 10 ##replicates
X = np.array([np.ones(N)]).T ##Design matrix
kernel = GPy.kern.Exponential(1,1,0.1) ##Covariance Function
noise_var = 0.01 ##Nugget variance
# 1000 points evenly spaced over [0,1]
s = np.linspace(0,1,N).reshape(-1,1)
mu = np.ones(N).reshape(-1,1) # vector of the means
nugget = np.eye(N) * noise_var ##Nugget matrix
cov_mat = kernel.K(s) + nugget ##Covariance matrix
# Generate M sample path with mean mu and covariance C
np.random.seed(1)
y = np.random.multivariate_normal(mu[:,0],cov_mat,M).T

# %%
plt.plot(s,y[:,0],".",mew=1.5)
plt.show()
plt.savefig("trueGP.pdf")

# %% [markdown]
# ### Create a neural network with three hidden layers (as mentioned in S2)

# %%
def create_mlp_3(feature_dim):
    # create model
    model = Sequential()
    
    # Hidden layers
    model.add(Dense(100, input_dim=feature_dim, kernel_initializer='he_normal', activation='relu'))
    model.add(Dense(100, activation='relu'))
    model.add(Dropout(0.5))
    model.add(BatchNormalization())
    model.add(Dense(100, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(100, activation='relu'))
    model.add(BatchNormalization())
    model.add(Dense(1, activation='linear'))
    
    # Compile model
    model.compile(loss='mse', optimizer='adam', metrics=['mse','mae'])
    return model

def create_mlp_7(feature_dim):
   # create model
    model = Sequential()
    
    # Hidden layers
    model.add(Dense(100, input_dim = feature_dim,  kernel_initializer='he_normal', activation='relu'))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(1, activation='linear'))

    # Compile model
    model.compile(loss='mse', optimizer='adam', metrics=['mse','mae'])
    return model### Create a neural network with 7 hidden layers

def create_mlp_6w(feature_dim):
   # create model
    model = Sequential()
    
    # Hidden layers
    model.add(Dense(400, input_dim = feature_dim,  kernel_initializer='he_normal', activation='relu'))
    model.add(Dense(200, activation='relu'))
    model.add(Dense(200, activation='relu'))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(100, activation='relu'))
    model.add(Dense(1, activation='linear'))

    # Compile model
    model.compile(loss='mse', optimizer='adam', metrics=['mse','mae'])
    return model### Create a neural network with 7 hidden layers

# %% [markdown]
# ### Generate Basis Functions

# %%
# 1 Dimensional basis functions
num_basis_1D = [10,19,37,73]
knots_1D = [np.linspace(0,1,i) for i in num_basis_1D]
K_1D = np.sum(num_basis_1D) ## basis size
## Wendland kernel
K_1DW = 0 ## basis size
phi_1DW = np.zeros((N, sum(num_basis_1D)))
for res in range(len(num_basis_1D)):
    theta = 1/num_basis_1D[res]*2.5
    for i in range(num_basis_1D[res]):
        d = np.absolute(s-knots_1D[res][i])/theta
        for j in range(len(d)):
            if d[j] >= 0 and d[j] <= 1:
                phi_1DW[j,i + K_1DW] = (1-d[j])**6 * (35 * d[j]**2 + 18 * d[j] + 3)/3
            else:
                phi_1DW[j,i + K_1DW] = 0
    K_1DW = K_1DW + num_basis_1D[res]
    
## Gaussian kernel
K_1DG = 0 ## basis size
phi_1DG = np.zeros((N, sum(num_basis_1D)))
for res in range(len(num_basis_1D)):
    theta = 1/num_basis_1D[res]
    for i in range(num_basis_1D[res]):
        d = np.absolute(s-knots_1D[res][i])/theta
        for j in range(len(d)):
            phi_1DG[j,i + K_1DG] = np.exp(-d[j]**2)
    K_1DG = K_1DG + num_basis_1D[res]
    
## triangular kernel
K_1DT = 0 ## basis size
phi_1DT = np.zeros((N, sum(num_basis_1D)))
for res in range(len(num_basis_1D)):
    theta = 1/num_basis_1D[res]*1.5
    for i in range(num_basis_1D[res]):
        d = np.absolute(s-knots_1D[res][i])/theta
        for j in range(len(d)):
            if d[j] >= 0 and d[j] <= 1:
                phi_1DT[j,i + K_1DT] = 1-d[j]
            else:
                phi_1DT[j,i + K_1DT] = 0
    K_1DT = K_1DT + num_basis_1D[res]

# %%
print(np.mean(phi_1DW[:,0]), np.mean(phi_1DG[:,0]), np.mean(phi_1DT[:,0]))
# Out:
# 0.07450000000000061 0.08903406985273053 0.07542542542542545

# %%
# visualize the basis functions
## Wendland functions
plt.imshow(phi_1DW, aspect='auto', cmap='viridis')
plt.colorbar(label='Value')
plt.title('Heatmap of phi_1DW')
plt.xlabel('Basis Functions')
plt.ylabel('Data Points')
plt.show()

## Gaussian functions
plt.imshow(phi_1DG, aspect='auto', cmap='viridis')
plt.colorbar(label='Value')
plt.title('Heatmap of phi_1DG')
plt.xlabel('Basis Functions')
plt.ylabel('Data Points')
plt.show()

## Triangular functions
plt.imshow(phi_1DT, aspect='auto', cmap='viridis')
plt.colorbar(label='Value')
plt.title('Heatmap of phi_1DT')
plt.xlabel('Basis Functions')
plt.ylabel('Data Points')
plt.show()

# %%
print(s.shape)
print(X.shape)
print(y.shape)
print(phi_1DW.shape)
# Out:
# (1000, 1)
# (1000, 1)
# (1000, 10)
# (1000, 139)

# %%
from sklearn.model_selection import train_test_split
indices = np.arange(N)
## Split the training and testing sets
s_train, s_test, X_train, X_test, phi_1DW_train, phi_1DW_test \
    , phi_1DG_train, phi_1DG_test, phi_1DT_train, phi_1DT_test \
    , y_train, y_test, idx_train, idx_test \
    = train_test_split(s, X, phi_1DW, phi_1DG, phi_1DT, y, indices, test_size=0.2)
N_train = s_train.shape[0]
N_test = s_test.shape[0]

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_scaled = scaler.transform(X)

# %%
def temp_model(feature_dim):
    #return create_mlp_3(feature_dim)
    return create_mlp_6w(feature_dim)

# %%
model_1 = temp_model(feature_dim = P)
model_2 = temp_model(feature_dim = P + 1)
model_3 = temp_model(feature_dim = P + K_1D)
model_4 = temp_model(feature_dim = P + K_1D)
model_5 = temp_model(feature_dim = P + K_1D)
# Out:
#  c:\Users\kgy90\OneDrive\문서\GitHub\Deepkriging_self\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning:Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
# model with only 1
# train the model
print("[INFO] training model 1...")
model_1.fit(X_train_scaled, y_train[:,0], epochs = 200, batch_size = 32, verbose = 0)
# Out:
#  c:\Users\kgy90\OneDrive\문서\GitHub\Deepkriging_self\.venv\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning:Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# [INFO] training model 1...

# %%
# model with coordinates
Xs_train_scaled = np.hstack((X_train_scaled,s_train))
# train the model
print("[INFO] training model 2...")
model_2.fit(Xs_train_scaled, y_train[:,0], epochs = 200, batch_size = 32, verbose = 0)
# Out:
# [INFO] training model 2...

# %%
# model 1D basis functions
## Wendland functions
XRBFW_train_scaled = np.hstack((X_train_scaled,phi_1DW_train))
# train the model
print("[INFO] training model 3...")
model_3.fit(XRBFW_train_scaled, y_train[:,0], epochs = 200, batch_size = 32, verbose = 0)

## Gaussian functions
XRBFG_train_scaled = np.hstack((X_train_scaled,phi_1DG_train))
# train the model
print("[INFO] training model 4...")
model_4.fit(XRBFG_train_scaled, y_train[:,0], epochs = 200, batch_size = 32, verbose = 0)

## Triangular functions
XRBFT_train_scaled = np.hstack((X_train_scaled,phi_1DT_train))
# train the model
print("[INFO] training model 5...")
model_5.fit(XRBFT_train_scaled, y_train[:,0], epochs = 200, batch_size = 32, verbose = 0)
# Out:
# [INFO] training model 3...
# [INFO] training model 4...
# [INFO] training model 5...

# %%
Xs_scaled = np.hstack((X_scaled,s))
XRBFW_scaled = np.hstack((X_scaled,phi_1DW))
XRBFG_scaled = np.hstack((X_scaled,phi_1DG))
XRBFT_scaled = np.hstack((X_scaled,phi_1DT))
y0_test_1 = model_1.predict(X_scaled)
y0_test_2 = model_2.predict(Xs_scaled)
y0_test_3 = model_3.predict(XRBFW_scaled)
y0_test_4 = model_4.predict(XRBFG_scaled)
y0_test_5 = model_5.predict(XRBFT_scaled)
print([y0_test_1.shape,y0_test_2.shape,y0_test_3.shape,y0_test_4.shape,y0_test_5.shape])
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [(1000, 1), (1000, 1), (1000, 1), (1000, 1), (1000, 1)]

# %%
##Warning: it is important to write 0:1 in GPRegression to get the size (Ntrain,1)
m = GPy.models.GPRegression(s_train,y_train[:,0:1] - mu[idx_train], kernel, noise_var = noise_var)
mu_GP,var_GP = m.predict(s)
lo95_GP,up95_GP = m.predict_quantiles(s)
y0_gp = mu_GP + mu
print(y0_gp.shape)
# Out:
# (1000, 1)

# %%
kernel2 = GPy.kern.Matern32(1,1,1)
m2 = GPy.models.GPRegression(s_train,y_train[:,0:1] - mu[idx_train],kernel2, noise_var = noise_var)
m2.optimize()
mu_GPE,var_GPE = m2.predict(s)
lo95_GPE,up95_GPE = m2.predict_quantiles(s)
y0_gpe = mu_GPE + mu
print(y0_gpe.shape)
# Out:
# (1000, 1)

# %%
import pylab
pylab.plot(s, y[:,0],".",label="Observation")
pylab.plot(s, y0_test_1,'blue',label="DNN with intercept")
pylab.plot(s, y0_test_2,'pink',label="DNN with intercept and coordinates")
pylab.plot(s, y0_test_3,'red',label="DeepKriging_Wendland")
pylab.plot(s, y0_test_4,'green',label="DeepKriging_Gaussian")
pylab.plot(s, y0_test_5,'orange',label="DeepKriging_Triangular")
pylab.plot(s, y0_gpe,'black',label="Kriging with Matern covariance")
pylab.plot(s, y0_gp,'grey',label="Kriging with exponetial covariance")
pylab.legend(loc='upper right')
pylab.show()
#plt.savefig("1D_compare.pdf")

# %%
def rmse(y_true,y_pred):
    rmse = np.sqrt(np.mean((y_true-y_pred)**2))
    return float(rmse)
def mape(y_true,y_pred):
    mape = np.mean(np.absolute(y_true-y_pred)/np.absolute(y_true))
    return float(mape)

# %%
rmse_train_combine = np.zeros((7,M))
mape_train_combine = np.zeros((7,M))
rmse_test_combine = np.zeros((7,M))
mape_test_combine = np.zeros((7,M))

for i in range(M):
    print("[INFO] training %s-th replicate..." % (i+1))
    ##Kriging with exponential covariance
    m = GPy.models.GPRegression(s_train,y_train[:,i:(i+1)], kernel, noise_var = noise_var)
    mu_GP_train,var_GP_train = m.predict(s_train)
    y_gp_train = mu_GP_train
    mu_GP_test,var_GP_test = m.predict(s_test)
    y_gp_test = mu_GP_test
    mu_gp,var_GP = m.predict(s)
    y_gp = mu_gp

    ##Kriging with Matern covariance
    kernel2 = GPy.kern.Matern32(1,1,1)
    m2 = GPy.models.GPRegression(s_train,y_train[:,i:(i+1)],kernel2, noise_var = noise_var)
    m2.optimize()
    mu_GPE_train,var_GPE_train = m2.predict(s_train)
    y_gpe_train = mu_GPE_train
    mu_GPE_test,var_GPE_test = m2.predict(s_test)
    y_gpe_test = mu_GPE_test
    mu_GPE,var_GPE = m2.predict(s)
    y_gpe = mu_GPE
    
    epochs_size = 100 ##Number of epochs

    ##DNN with intercept
    model_1.fit(X_train_scaled, y_train[:,i], epochs = epochs_size, batch_size = 32, verbose = 0)
    y_dnn_train = model_1.predict(X_scaled[idx_train,:])
    y_dnn_test = model_1.predict(X_scaled[idx_test,:])
    y_dnn = model_1.predict(X_scaled)

    ##DNN with intercept and coordinate
    model_2.fit(Xs_train_scaled, y_train[:,i], epochs = epochs_size, batch_size = 32, verbose = 0)
    y_dnn2_train = model_2.predict(Xs_scaled[idx_train,:])
    y_dnn2_test = model_2.predict(Xs_scaled[idx_test,:])
    y_dnn2 = model_2.predict(Xs_scaled)

    ##DeepKriging with Wendland kernel
    model_3.fit(XRBFW_train_scaled, y_train[:,i], epochs = epochs_size, batch_size = 32, verbose = 0)
    y_dkw_train = model_3.predict(XRBFW_scaled[idx_train,:])
    y_dkw_test = model_3.predict(XRBFW_scaled[idx_test,:])
    y_dkw = model_3.predict(XRBFW_scaled)
    
    ##DeepKriging with Gaussian kernel
    model_4.fit(XRBFG_train_scaled, y_train[:,i], epochs = epochs_size, batch_size = 32, verbose = 0)
    y_dkg_train = model_4.predict(XRBFG_scaled[idx_train,:])
    y_dkg_test = model_4.predict(XRBFG_scaled[idx_test,:])
    y_dkg = model_4.predict(XRBFG_scaled)
    
    ##DeepKriging with Triangular kernel
    model_5.fit(XRBFT_train_scaled, y_train[:,i], epochs = epochs_size, batch_size = 32, verbose = 0)
    y_dkt_train = model_5.predict(XRBFT_scaled[idx_train,:])
    y_dkt_test = model_5.predict(XRBFT_scaled[idx_test,:])
    y_dkt = model_5.predict(XRBFT_scaled)

    ##Save the results
    rmse_train_combine[:,i] = np.array([rmse(y_train[:,i],y_gp_train[:,0]),\
                                  rmse(y_train[:,i],y_gpe_train[:,0]),\
                                  rmse(y_train[:,i],y_dnn_train[:,0]),\
                                  rmse(y_train[:,i],y_dnn2_train[:,0]),\
                                  rmse(y_train[:,i],y_dkw_train[:,0]),\
                                  rmse(y_train[:,i],y_dkg_train[:,0]),\
                                  rmse(y_train[:,i],y_dkt_train[:,0])])
    mape_train_combine[:,i] = np.array([mape(y_train[:,i],y_gp_train[:,0]),\
                                  mape(y_train[:,i],y_gpe_train[:,0]),\
                                  mape(y_train[:,i],y_dnn_train[:,0]),\
                                  mape(y_train[:,i],y_dnn2_train[:,0]),\
                                  mape(y_train[:,i],y_dkw_train[:,0]),\
                                  mape(y_train[:,i],y_dkg_train[:,0]),\
                                  mape(y_train[:,i],y_dkt_train[:,0])])
    rmse_test_combine[:,i] = np.array([rmse(y_test[:,i],y_gp_test[:,0]),\
                                  rmse(y_test[:,i],y_gpe_test[:,0]),\
                                  rmse(y_test[:,i],y_dnn_test[:,0]),\
                                  rmse(y_test[:,i],y_dnn2_test[:,0]),\
                                  rmse(y_test[:,i],y_dkw_test[:,0]),\
                                  rmse(y_test[:,i],y_dkg_test[:,0]),\
                                  rmse(y_test[:,i],y_dkt_test[:,0])])
    mape_test_combine[:,i] = np.array([mape(y_test[:,i],y_gp_test[:,0]),\
                                  mape(y_test[:,i],y_gpe_test[:,0]),\
                                  mape(y_test[:,i],y_dnn_test[:,0]),\
                                  mape(y_test[:,i],y_dnn2_test[:,0]),\
                                  mape(y_test[:,i],y_dkw_test[:,0]),\
                                  mape(y_test[:,i],y_dkg_test[:,0]),\
                                  mape(y_test[:,i],y_dkt_test[:,0])])

    print(i+1,"th replicate:")
    print(rmse_train_combine[:,i])
    print(mape_train_combine[:,i])
    print(rmse_test_combine[:,i])
    print(mape_test_combine[:,i])
    
    plt.figure()    
    pylab.plot(s, y[:,i],".",label="Observation")
    pylab.plot(s, y_dnn,'blue',label="DNN with intercept")
    pylab.plot(s, y_dnn2,'pink',label="DNN with intercept and coordinates")
    pylab.plot(s, y_dkw,'red',label="DeepKriging_Wendland")
    pylab.plot(s, y_dkg,'green',label="DeepKriging_Gaussian")
    pylab.plot(s, y_dkt,'orange',label="DeepKriging_Triangular")
    pylab.plot(s, y_gpe,'black',label="Kriging with Matern covariance")
    pylab.plot(s, y_gp,'grey',label="Kriging with exponetial covariance")
    pylab.legend(loc='upper right')
    plt.savefig("1D_compare_%sth.pdf" % (i+1))
# Out:
# [INFO] training 1-th replicate...
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step
# 1 th replicate:
# [0.06233296 0.12926452 1.03892796 0.33552846 0.12720094 0.13579627
#  0.13353727]
# [0.54575317 1.02781426 6.1611839  2.46387299 1.23770199 1.09367736
#  0.8891998 ]
# [0.15683535 0.16167359 1.00709967 0.33734675 0.1620566  0.17037418
#  0.16862614]
# [0.76122409 0.85878104 2.82303314 0.99124286 0.70068294 0.73228865
#  0.81243712]
# [INFO] training 2-th replicate...
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 2 th replicate:
# [0.06298841 0.12959901 1.23128754 0.42879308 0.1224984  0.1323829
#  0.12692929]
# [0.14654618 0.32313599 2.42758649 0.84732569 0.25481064 0.21993207
#  0.2241622 ]
# [0.17401139 0.180442   1.23793622 0.46234388 0.18300604 0.19396028
#  0.18308998]
# [0.15160037 0.15974268 1.19949036 0.48860405 0.1675994  0.16464627
#  0.15852762]
# [INFO] training 3-th replicate...
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step
# 3 th replicate:
# [0.06072573 0.12489579 0.77772083 0.35877123 0.1111138  0.1213581
#  0.12009728]
# [0.26150519 0.5094535  3.52330553 1.07764155 0.41259587 0.45438092
#  0.45846431]
# [0.15570607 0.16147112 0.78601492 0.34135853 0.17522962 0.17301306
#  0.18069107]
# [0.28749724 0.30847823 2.13039626 0.85820184 0.37094682 0.30479349
#  0.31634954]
# [INFO] training 4-th replicate...
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step
# 4 th replicate:
# [0.0631915  0.12727768 0.80708896 0.35765732 0.11141559 0.11372389
#  0.11045701]
# [0.24934204 0.51251279 4.78526544 1.42535857 0.40673128 0.51494367
#  0.3984782 ]
# [0.16280544 0.1750389  0.85401268 0.38581697 0.16975942 0.17131642
#  0.16653338]
# [0.62631223 0.65485479 3.46002091 1.68156487 0.54491736 0.70402175
#  0.60889559]
# [INFO] training 5-th replicate...
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 5 th replicate:
# [0.06437516 0.12585049 0.77003575 0.28693664 0.10607591 0.11648212
#  0.10689598]
# [0.15136688 0.29836193 2.8364129  0.75255923 0.20600637 0.22675598
#  0.24094807]
# [0.15370726 0.16264282 0.69483608 0.27301634 0.16230672 0.1590683
#  0.17130205]
# [0.38687842 0.44061446 3.12610047 0.95278771 0.48596944 0.45764054
#  0.43903787]
# [INFO] training 6-th replicate...
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step
# 6 th replicate:
# [0.0621533  0.12671898 0.80741245 0.25137971 0.10779767 0.10616674
#  0.10822626]
# [0.09850704 0.19550395 2.79474292 0.30733519 0.15458149 0.17644917
#  0.16157752]
# [0.15769543 0.16400103 0.8739493  0.26069894 0.16370339 0.16677943
#  0.17272459]
# [0.2057043  0.22158692 2.06478255 0.26680209 0.20341518 0.22802075
#  0.19697332]
# [INFO] training 7-th replicate...
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step
# 7 th replicate:
# [0.0615294  0.13075618 0.70391454 0.24057056 0.10544981 0.10429718
#  0.09476885]
# [0.02538612 0.05435857 0.31478133 0.09193757 0.03810317 0.03910992
#  0.03557783]
# [0.16021119 0.1725815  0.71563413 0.24403111 0.1648477  0.18120331
#  0.1758054 ]
# [0.06426347 0.07048094 0.30585377 0.09220755 0.066149   0.07364403
#  0.06853599]
# [INFO] training 8-th replicate...
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step
# 8 th replicate:
# [0.06411245 0.12936637 0.80654765 0.23898749 0.10205332 0.09776712
#  0.10057797]
# [0.35176771 0.65611311 4.26406852 1.06248262 0.52805688 0.6868883
#  0.55308009]
# [0.1420057  0.14796231 0.77938056 0.2178261  0.14953903 0.14735903
#  0.15544243]
# [0.65559061 0.76701291 3.45520234 0.96991676 0.59958916 0.66862184
#  0.59514685]
# [INFO] training 9-th replicate...
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 836us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 9 th replicate:
# [0.06521925 0.13227863 1.31076035 0.25680245 0.11008496 0.10910651
#  0.09869984]
# [0.11846107 0.25835122 3.8947069  0.47485169 0.20342911 0.2173149
#  0.22957948]
# [0.16161811 0.16909731 1.29374108 0.25801988 0.17575551 0.16857614
#  0.16994819]
# [0.28810158 0.31104496 3.4223728  0.45823286 0.32292499 0.30131892
#  0.30634521]
# [INFO] training 10-th replicate...
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 869us/step
# 10 th replicate:
# [0.05999338 0.11869404 0.94377428 0.24343264 0.09193546 0.08924755
#  0.08717751]
# [0.14801584 0.29006413 2.53119419 0.57999405 0.21076438 0.16545212
#  0.17079361]
# [0.14360412 0.14593763 0.98341294 0.22106602 0.17035239 0.15263906
#  0.15529366]
# [174.24925979 173.2612166  342.1094454   88.04105402 260.96125425
#  142.94084416 185.72597071]

# %%
print(np.mean(rmse_train_combine,axis=1))
print(np.std(rmse_train_combine,axis=1))
print(np.mean(mape_train_combine,axis=1))
print(np.std(mape_train_combine,axis=1))
# Out:
# [0.06266215 0.12747017 0.91974703 0.29988596 0.10956259 0.11263284
#  0.10873673]
# [0.00156479 0.00363509 0.19799593 0.06283557 0.00940134 0.0138215
#  0.01381634]
# [0.20966512 0.41256694 3.35332481 0.90833592 0.36527812 0.37949044
#  0.33618611]
# [0.14255748 0.26315012 1.49769213 0.63959732 0.32103806 0.30108092
#  0.2351366 ]

# %%
print(np.mean(rmse_test_combine,axis=1))
print(np.std(rmse_test_combine,axis=1))
print(np.mean(mape_test_combine,axis=1))
print(np.std(mape_test_combine,axis=1))
# Out:
# [0.15682001 0.16408482 0.92260176 0.30015245 0.16765564 0.16842892
#  0.16994569]
# [0.00878471 0.01043482 0.19722341 0.07548233 0.00884298 0.01277417
#  0.00877807]
# [17.76764321 17.70538135 36.4096698   9.48006146 26.44234485 14.65758404
#  18.92282198]
# [ 52.16100015  51.85254495 101.9048238   26.1905235   78.17320481
#   42.76165786  55.60147893]

# %%
result_combine = np.vstack((np.mean(rmse_train_combine,axis=1),np.std(rmse_train_combine,axis=1),\
                            np.mean(rmse_test_combine,axis=1),np.std(rmse_test_combine,axis=1),\
                            np.mean(mape_train_combine,axis=1),np.std(mape_train_combine,axis=1),\
                            np.mean(mape_test_combine,axis=1),np.std(mape_test_combine,axis=1))).T

# %%
import pandas as pd
# Define row and column names
col_names = ['mean_rmse_train', 'std_rmse_train', 'mean_rmse_test', 'std_rmse_test',
             'mean_mape_train', 'std_mape_train', 'mean_mape_test', 'std_mape_test']
row_names = ['Kriging_exp', 'Kriging_Matern', 'only x=1', 'base DNN', 'DK_Wendland', 'DK_Gaussian', 'DK_Triangular']

# Convert to DataFrame
df_result_combine = pd.DataFrame(result_combine, index=row_names, columns=col_names)

# Display the DataFrame
print(df_result_combine)
# Out:
#                 mean_rmse_train  std_rmse_train  mean_rmse_test  \
# Kriging_exp            0.062662        0.001565        0.156820
# Kriging_Matern         0.127470        0.003635        0.164085
# only x=1               0.919747        0.197996        0.922602
# base DNN               0.299886        0.062836        0.300152
# DK_Wendland            0.109563        0.009401        0.167656
# DK_Gaussian            0.112633        0.013821        0.168429
# DK_Triangular          0.108737        0.013816        0.169946
#
#                 std_rmse_test  mean_mape_train  std_mape_train  \
# Kriging_exp          0.008785         0.209665        0.142557
# Kriging_Matern       0.010435         0.412567        0.263150
# only x=1             0.197223         3.353325        1.497692
# base DNN             0.075482         0.908336        0.639597
# DK_Wendland          0.008843         0.365278        0.321038
# DK_Gaussian          0.012774         0.379490        0.301081
# DK_Triangular        0.008778         0.336186        0.235137
#
#                 mean_mape_test  std_mape_test
# Kriging_exp          17.767643      52.161000
# Kriging_Matern       17.705381      51.852545
# only x=1             36.409670     101.904824
# base DNN              9.480061      26.190524
# DK_Wendland          26.442345      78.173205
# DK_Gaussian          14.657584      42.761658
# DK_Triangular        18.922822      55.601479

# %%
df_result_combine.to_csv("1D_compare.csv")

# %%
row_to_include = [0,1,3,4,5,6]
rmse_train_data= rmse_train_combine[row_to_include,:].T
fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)

# Creating axes instance
bp = ax.boxplot(rmse_train_data, patch_artist = True,
                notch ='True', vert = 0)

colors = ['#0000FF', '#00FF00', '#FFFF00','#FF00FF','#FF0000','#00FFFF']

for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)

# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='black',
                linewidth = 1.5,
                linestyle =":")

# changing color and linewidth of
# caps
for cap in bp['caps']:
    cap.set(color ='#8B008B',
            linewidth = 2)

# changing color and linewidth of
# medians
for median in bp['medians']:
    median.set(color ='red',
               linewidth = 3)

# changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D',
              color ='#e7298a',
              alpha = 0.5)

# x-axis labels
ax.set_yticklabels(['Kriging_exp', 'Kriging_Matern', 'base DNN', 'DK_Wendland', 'DK_Gaussian', 'DK_Triangular'])

# Adding title
plt.title("(a)")
plt.xlabel('Train Root Mean Squared Error based on 10-replicate')
#plt.xlim((0,0.02))
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

# show plot
#plt.show(bp)
plt.savefig("boxplot_1D_rmse_train.pdf")

# %%
row_to_include = [0,1,3,4,5,6]
rmse_test_data= rmse_test_combine[row_to_include,:].T
fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)

# Creating axes instance
bp = ax.boxplot(rmse_test_data, patch_artist = True,
                notch ='True', vert = 0)

colors = ['#0000FF', '#00FF00', '#FFFF00','#FF00FF','#FF0000','#00FFFF']

for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)

# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='black',
                linewidth = 1.5,
                linestyle =":")

# changing color and linewidth of
# caps
for cap in bp['caps']:
    cap.set(color ='#8B008B',
            linewidth = 2)

# changing color and linewidth of
# medians
for median in bp['medians']:
    median.set(color ='red',
               linewidth = 3)

# changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D',
              color ='#e7298a',
              alpha = 0.5)

# x-axis labels
ax.set_yticklabels(['Kriging_exp', 'Kriging_Matern', 'base DNN', 'DK_Wendland', 'DK_Gaussian', 'DK_Triangular'])

# Adding title
plt.title("(a)")
plt.xlabel('Test Root Mean Squared Error based on 10-replicate')
#plt.xlim((0,0.02))
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

# show plot
#plt.show(bp)
plt.savefig("boxplot_1D_rmse_test.pdf")

# %%
row_to_include = [0,1,3,4,5,6]
mape_train_data= mape_train_combine[row_to_include,:].T
fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)

# Creating axes instance
bp = ax.boxplot(mape_train_data, patch_artist = True,
                notch ='True', vert = 0)

colors = ['#0000FF', '#00FF00', '#FFFF00','#FF00FF','#FF0000','#00FFFF']

for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)

# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='black',
                linewidth = 1.5,
                linestyle =":")

# changing color and linewidth of
# caps
for cap in bp['caps']:
    cap.set(color ='#8B008B',
            linewidth = 2)

# changing color and linewidth of
# medians
for median in bp['medians']:
    median.set(color ='red',
               linewidth = 3)

# changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D',
              color ='#e7298a',
              alpha = 0.5)

# x-axis labels
ax.set_yticklabels(['Kriging_exp', 'Kriging_Matern', 'base DNN', 'DK_Wendland', 'DK_Gaussian', 'DK_Triangular'])

# Adding title
plt.title("(a)")
plt.xlabel('Train Mean Absolute Percentage Error based on 10-replicate')
plt.xlim((0,1.5))
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

# show plot
#plt.show(bp)
plt.savefig("boxplot_1D_mape_train.pdf")

# %%
row_to_include = [0,1,3,4,5,6]
mape_test_data= mape_test_combine[row_to_include,:].T
fig = plt.figure(figsize =(10, 7))
ax = fig.add_subplot(111)

# Creating axes instance
bp = ax.boxplot(mape_test_data, patch_artist = True,
                notch ='True', vert = 0)

colors = ['#0000FF', '#00FF00', '#FFFF00','#FF00FF','#FF0000','#00FFFF']

for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)

# changing color and linewidth of
# whiskers
for whisker in bp['whiskers']:
    whisker.set(color ='black',
                linewidth = 1.5,
                linestyle =":")

# changing color and linewidth of
# caps
for cap in bp['caps']:
    cap.set(color ='#8B008B',
            linewidth = 2)

# changing color and linewidth of
# medians
for median in bp['medians']:
    median.set(color ='red',
               linewidth = 3)

# changing style of fliers
for flier in bp['fliers']:
    flier.set(marker ='D',
              color ='#e7298a',
              alpha = 0.5)

# x-axis labels
ax.set_yticklabels(['Kriging_exp', 'Kriging_Matern', 'base DNN', 'DK_Wendland', 'DK_Gaussian', 'DK_Triangular'])

# Adding title
plt.title("(a)")
plt.xlabel('Test Mean Absolute Percentage Error based on 10-replicate')
plt.xlim((0,1.5))
# Removing top axes and right axes
# ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()

# show plot
#plt.show(bp)
plt.savefig("boxplot_1D_mape_test.pdf")
